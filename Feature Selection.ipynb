# %% [markdown]
# # Feature Selection and Preprocessing

# %% [markdown]
# | Code   | Description   |
# |:---|:---|
# |**school** | student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira) |
# |**sex**  | student's sex (binary: "F" - female or "M" - male) |
# |**age**  | student's age (numeric: from 15 to 22) |
# |**address**  | student's home address type (binary: "U" - urban or "R" - rural) |
# |**famsize**  | family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3) |
# |**Pstatus**  | parent's cohabitation status (binary: "T" - living together or "A" - apart) |
# |**Medu**  | mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education) |
# |**Fedu**  | father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education) |
# |**Mjob**  | mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other") |
# |**Fjob**  | father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other") |
# |**reason**  | reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other") |
# |**guardian**  | student's guardian (nominal: "mother", "father" or "other") |
# |**traveltime**  | home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour) |
# |**studytime**  | weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours) |
# |**failures**  | number of past class failures (numeric: n if 1<=n<3, else 4) |
# |**schoolsup**  | extra educational support (binary: yes or no)|
# |**famsup**  | family educational support (binary: yes or no) |
# |**paid**  | extra paid classes within the course subject (Math or Portuguese) (binary: yes or no) |
# |**activities**  | extra-curricular activities (binary: yes or no) |
# |**nursery**  | attended nursery school (binary: yes or no) |
# |**higher**  | wants to take higher education (binary: yes or no) |
# |**internet**  | Internet access at home (binary: yes or no) |
# |**romantic**  | with a romantic relationship (binary: yes or no) |
# |**famrel**  | quality of family relationships (numeric: from 1 - very bad to 5 - excellent) |
# |**freetime**  | free time after school (numeric: from 1 - very low to 5 - very high) |
# |**goout**  | going out with friends (numeric: from 1 - very low to 5 - very high) |
# |**Dalc**  | workday alcohol consumption (numeric: from 1 - very low to 5 - very high) |
# |**Walc**  | weekend alcohol consumption (numeric: from 1 - very low to 5 - very high) |
# |**health**  | current health status (numeric: from 1 - very bad to 5 - very good) |
# |**absences**  | number of school absences (numeric: from 0 to 93) |
# |**G1**  | first period grade (numeric: from 0 to 20) |
# |**G2**  | second period grade (numeric: from 0 to 20) |
# |**G3**  | final grade (numeric: from 0 to 20, output target) |

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
#sns.set(color_codes=True)
# %matplotlib inline

#When using the 'inline' backend, your matplotlib graphs will be included in your notebook, 
#next to the code,within frontends like the Jupyter notebook

# %%
math_df=pd.read_csv('student-mat.csv', sep=";")

# %%
por_df=pd.read_csv('student-por.csv', sep=";")

# %%
frames = [math_df, por_df]

# %%
df = pd.concat(frames)

# %%
le = preprocessing.LabelEncoder()

# Encode labels in column 'sex'.
df ['sex']= le.fit_transform(df['sex'])

#address
df ['address']= le.fit_transform(df['address'])

#famsize
df ['famsize']= le.fit_transform(df['famsize'])

#Pstatus
df ['Pstatus']= le.fit_transform(df['Pstatus'])

#Mjob
df ['Mjob']= le.fit_transform(df['Mjob'])

#Fjob
df ['Fjob']= le.fit_transform(df['Fjob'])

#reason
df ['reason']= le.fit_transform(df['reason'])

#guardian
df ['guardian']= le.fit_transform(df['guardian'])

#schoolsup
df ['schoolsup']= le.fit_transform(df['schoolsup'])

#famsup
df ['famsup']= le.fit_transform(df['famsup'])

#paid
df ['paid']= le.fit_transform(df['paid'])

#activities
df ['activities']= le.fit_transform(df['activities'])

#nursery
df ['nursery']= le.fit_transform(df['nursery'])

#higher
df ['higher']= le.fit_transform(df['higher'])

#internet
df ['internet']= le.fit_transform(df['internet'])

#romantic
df ['romantic']= le.fit_transform(df['romantic'])

#school
df ['school']= le.fit_transform(df['school'])

# %% [raw]
# df

# %%
df.describe(include='all')
# Out:
#             school          sex          age      address      famsize  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.260536     0.433908    16.726054     0.727011     0.293103
# std       0.439138     0.495850     1.239975     0.445708     0.455404
# min       0.000000     0.000000    15.000000     0.000000     0.000000
# 25%       0.000000     0.000000    16.000000     0.000000     0.000000
# 50%       0.000000     0.000000    17.000000     1.000000     0.000000
# 75%       1.000000     1.000000    18.000000     1.000000     1.000000
# max       1.000000     1.000000    22.000000     1.000000     1.000000
#
#            Pstatus         Medu         Fedu         Mjob         Fjob  ...  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000  ...
# mean      0.884100     2.603448     2.387931     2.027778     2.246169  ...
# std       0.320259     1.124907     1.099938     1.244815     0.863522  ...
# ...

# %%
all=df.iloc[:,:-1]
#removing the target from the 
g3=df.iloc[:,-1]

# %%
all
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 644       1    0   19        0        0        1     2     3     3     2  ...
# 645       1    0   18        1        1        1     3     1     4     3  ...
# 646       1    0   18        1        0        1     1     1     2     2  ...
# 647       1    1   17        1        1        1     3     1     3     3  ...
# 648       1    1   18        0        1        1     3     2     3     2  ...
#
# ...

# %%
g3
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 644    10
# 645    16
# 646     9
# 647    10
# 648    11
# Name: G3, Length: 1044, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(all,g3,test_size=0.3,random_state=0)

# %% [markdown]
# # 1.Chi square

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
f_score=chi2(X_train,y_train)

# %%
f_score
# Out:
# (array([ 35.84980495,   6.99377266,   3.10000401,   9.8839218 ,
#          13.24185283,   0.70961765,  24.96471055,  21.46106498,
#          31.27083548,   6.5171899 ,  41.9850117 ,   8.61694931,
#          13.74390256,  14.16438354, 272.09522811,  32.65607036,
#           7.22300869,  22.03994258,  11.09455819,   2.64222889,
#           4.39007777,   5.11146234,  23.52446299,   2.74983581,
#           5.45110876,  11.36168715,  26.19674347,  35.74284286,
#          14.31809069, 627.43141106, 462.98529929, 665.65681804]),
#  array([7.37521094e-003, 9.90178750e-001, 9.99964358e-001, 9.35629169e-001,
#         7.77009482e-001, 1.00000000e+000, 1.25891349e-001, 2.56792804e-001,
#         2.67778580e-002, 9.93605365e-001, 1.11123583e-003, 9.67967085e-001,
#         7.45626751e-001, 7.18314133e-001, 2.54325480e-047, 1.83624231e-002,
#         9.88107099e-001, 2.30216639e-001, 8.90301008e-001, 9.99989634e-001,
#         9.99537912e-001, 9.98675685e-001, 1.71232436e-001, 9.99985845e-001,
# ...

# %%
pvalue=pd.Series(f_score[1])
pvalue.index=X_train.columns
pvalue.sort_values(ascending=True)
# Out:
# G2            1.089519e-129
# absences      1.358161e-121
# G1             6.165976e-87
# failures       2.543255e-47
# reason         1.111236e-03
# school         7.375211e-03
# Walc           7.610764e-03
# schoolsup      1.836242e-02
# Mjob           2.677786e-02
# Dalc           9.534378e-02
# Medu           1.258913e-01
# romantic       1.712324e-01
# paid           2.302166e-01
# Fedu           2.567928e-01
# health         7.081323e-01
# studytime      7.183141e-01
# traveltime     7.456268e-01
# famsize        7.770095e-01
# goout          8.783829e-01
# activities     8.903010e-01
# address        9.356292e-01
# guardian       9.679671e-01
# famsup         9.881071e-01
# sex            9.901787e-01
# Fjob           9.936054e-01
# freetime       9.979630e-01
# internet       9.986757e-01
# higher         9.995379e-01
# age            9.999644e-01
# famrel         9.999858e-01
# nursery        9.999896e-01
# Pstatus        1.000000e+00
# dtype: float64

# %%
pd.DataFrame(pvalue.sort_values(ascending=True),columns=['pvalue'])
# Out:
#                    pvalue
# G2          1.089519e-129
# absences    1.358161e-121
# G1           6.165976e-87
# failures     2.543255e-47
# reason       1.111236e-03
# school       7.375211e-03
# Walc         7.610764e-03
# schoolsup    1.836242e-02
# Mjob         2.677786e-02
# Dalc         9.534378e-02
# Medu         1.258913e-01
# romantic     1.712324e-01
# paid         2.302166e-01
# Fedu         2.567928e-01
# health       7.081323e-01
# studytime    7.183141e-01
# traveltime   7.456268e-01
# famsize      7.770095e-01
# goout        8.783829e-01
# activities   8.903010e-01
# address      9.356292e-01
# guardian     9.679671e-01
# famsup       9.881071e-01
# sex          9.901787e-01
# Fjob         9.936054e-01
# freetime     9.979630e-01
# internet     9.986757e-01
# higher       9.995379e-01
# age          9.999644e-01
# famrel       9.999858e-01
# nursery      9.999896e-01
# Pstatus      1.000000e+00

# %%
bestfeatures = SelectKBest(score_func=chi2, k=32)
fit = bestfeatures.fit(X_train,y_train)

# %%
bestfeatures
# Out:
# SelectKBest(k=32, score_func=<function chi2 at 0x00000088CCF72048>)

# %%
fit
# Out:
# SelectKBest(k=32, score_func=<function chi2 at 0x00000088CCF72048>)

# %%
dfscores = pd.DataFrame(fit.scores_)

# %%
dfcolumns = pd.DataFrame(X_train.columns)

# %%
featureScores = pd.concat([dfcolumns,dfscores],axis=1)

# %%
featureScores.columns = ['Attribute','Ranking']  #naming the dataframe columns

# %%
featureScores.nlargest(10,'Ranking')
# Out:
#     Attribute     Ranking
# 31         G2  665.656818
# 29   absences  627.431411
# 30         G1  462.985299
# 14   failures  272.095228
# 10     reason   41.985012
# 0      school   35.849805
# 27       Walc   35.742843
# 15  schoolsup   32.656070
# 8        Mjob   31.270835
# 26       Dalc   26.196743

# %% [markdown]
# # 2.ExtraTree Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
extraTreesClassifier = ExtraTreesClassifier(n_estimators=100)
extraTreesClassifier.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
extraTreesClassifier.feature_importances_
# Out:
# array([0.01475229, 0.02099088, 0.03538362, 0.01497864, 0.02047636,
#        0.01188085, 0.03126221, 0.03187972, 0.03109133, 0.02735664,
#        0.02973808, 0.02157527, 0.02406207, 0.02797164, 0.02057356,
#        0.01307071, 0.0220468 , 0.02521965, 0.02124533, 0.01788397,
#        0.00801688, 0.0156177 , 0.0218873 , 0.02947125, 0.03129165,
#        0.03361428, 0.02089859, 0.03264032, 0.03183071, 0.05972615,
#        0.09991121, 0.15165435])

# %%
feat_importances = pd.Series(extraTreesClassifier.feature_importances_, index=X_train.columns)

# %%
feat_importances.nlargest(31)
# Out:
# G2            0.151654
# G1            0.099911
# absences      0.059726
# age           0.035384
# goout         0.033614
# Walc          0.032640
# Fedu          0.031880
# health        0.031831
# freetime      0.031292
# Medu          0.031262
# Mjob          0.031091
# reason        0.029738
# famrel        0.029471
# studytime     0.027972
# Fjob          0.027357
# paid          0.025220
# traveltime    0.024062
# famsup        0.022047
# romantic      0.021887
# guardian      0.021575
# activities    0.021245
# sex           0.020991
# Dalc          0.020899
# failures      0.020574
# famsize       0.020476
# nursery       0.017884
# internet      0.015618
# address       0.014979
# school        0.014752
# schoolsup     0.013071
# Pstatus       0.011881
# dtype: float64

# %%
plt.figure(figsize=[30,20])

# %%
f=feat_importances.nlargest(31).plot(kind='barh',figsize=(10,15))

# %%
f.figure.savefig('file.png')

# %% [markdown]
# # 3.Correlation matrix

# %% [markdown]
# ## Correlation with target variable

# %%
corrframe=df.corr()['G3'].abs().sort_values()

# %%
corrframe.nlargest(11)
# Out:
# G3           1.000000
# G2           0.910743
# G1           0.809142
# failures     0.383145
# higher       0.236578
# Medu         0.201472
# studytime    0.161629
# Fedu         0.159796
# Dalc         0.129642
# school       0.127114
# age          0.125282
# Name: G3, dtype: float64

# %%
corrframe.nlargest(11).plot(kind='barh',figsize=(5,5))

# %% [markdown]
# ## Correlated Attributes

# %%
X_train.corr()
# Out:
#               school       sex       age   address   famsize   Pstatus  \
# school      1.000000 -0.095144  0.198384 -0.333096  0.051708  0.019380
# sex        -0.095144  1.000000 -0.042090  0.000577  0.098672  0.050201
# age         0.198384 -0.042090  1.000000 -0.102611  0.022875 -0.033513
# address    -0.333096  0.000577 -0.102611  1.000000  0.026626 -0.051374
# famsize     0.051708  0.098672  0.022875  0.026626  1.000000 -0.198739
# Pstatus     0.019380  0.050201 -0.033513 -0.051374 -0.198739  1.000000
# Medu       -0.260110  0.108026 -0.100858  0.233603  0.008779 -0.070768
# Fedu       -0.226797  0.066698 -0.120665  0.174443 -0.026755 -0.052377
# Mjob       -0.163601  0.200119 -0.072939  0.181188  0.036775 -0.024763
# Fjob       -0.056890  0.089880 -0.087322  0.017526 -0.059114  0.055816
# reason     -0.140974 -0.044634  0.001232  0.050351  0.043233 -0.037333
# guardian   -0.003586 -0.072608  0.295454 -0.072204 -0.012391 -0.148323
# ...

# %%
mask = np.zeros_like(X_train.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# %%
plt.figure(figsize=(35,30));
sns.heatmap(X_train[X_train.columns].corr(),mask=mask,vmin=-1,annot=True, vmax=1 ,center=0,cmap="Set3")

# %% [markdown]
# ## 3.1 Using correlation to determine duplicate attributes (brute force approch)

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                print(corr_matrix.iloc[i,j])
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train,0.8)
len(set(corr_features))
# Out:
# 0.8574661467817534
# 1

# %%
corr_features
# Out:
# {'G2'}

# %%
X_train.drop(labels=corr_features,axis=1,inplace=True,errors='raise')
X_test.drop(labels=corr_features,axis=1,inplace=True,errors='raise')
# Out:
# C:\Users\ADMIN\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X_train.shape
# Out:
# (730, 31)

# %% [markdown]
# ## 3.2 Using correlation to determine duplicate attributes (second approch)

# %%
X_train,X_test,y_train,y_test=train_test_split(all,g3,test_size=0.3,random_state=0)

# %%
corrmat=X_train.corr()

# %%
corrmat.abs().unstack()
# Out:
# school  school      1.000000
#         sex         0.095144
#         age         0.198384
#         address     0.333096
#         famsize     0.051708
#                       ...
# G2      Walc        0.124585
#         health      0.095907
#         absences    0.054374
#         G1          0.857466
#         G2          1.000000
# Length: 1024, dtype: float64

# %%
corrmat=corrmat.abs().unstack()

# %%
corrmat.sort_values(ascending=False)
# Out:
# G2         G2           1.000000
# schoolsup  schoolsup    1.000000
# health     health       1.000000
# Walc       Walc         1.000000
# Dalc       Dalc         1.000000
#                           ...
# Medu       health       0.000578
# sex        address      0.000577
# address    sex          0.000577
# Fjob       romantic     0.000310
# romantic   Fjob         0.000310
# Length: 1024, dtype: float64

# %%
corrmat=corrmat.sort_values(ascending=False)

# %%
corrmat=corrmat[corrmat >= 0.8]

# %%
corrmat=corrmat[corrmat < 1]

# %%
corrmat
# Out:
# G1  G2    0.857466
# G2  G1    0.857466
# dtype: float64

# %%
corrmat=pd.DataFrame(corrmat).reset_index()

# %%
corrmat.columns=['Feature1','Feature2','corr']

# %%
corrmat
# Out:
#   Feature1 Feature2      corr
# 0       G1       G2  0.857466
# 1       G2       G1  0.857466

# %% [markdown]
# ## 4 roc-auc or mse

# %%
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.metrics import roc_auc_score,mean_squared_error
from sklearn.preprocessing import LabelBinarizer

# %%
X_train,X_test,y_train,y_test=train_test_split(all,g3,test_size=0.3,random_state=0)

# %%
y_train
# Out:
# 435    10
# 172    10
# 610     0
# 618    15
# 2      12
#        ..
# 638    16
# 368    11
# 440     0
# 164    10
# 289    17
# Name: G3, Length: 730, dtype: int64

# %% [markdown]
# ## 4.1 Classification

# %%
roc_values =[]

# %%
def multiclass_roc_auc_score(truth, pred, average="macro"):

    lb = LabelBinarizer()
    lb.fit(truth)

    truth = lb.transform(truth)
    pred = lb.transform(pred)

    return roc_auc_score(truth, pred, average=average)

# %%
for feature in X_train.columns:
    clf=DecisionTreeClassifier()
    clf.fit(X_train[feature].to_frame(),y_train)
    y_scored=clf.predict(X_test[feature].to_frame())
    print(y_scored)
    roc_values.append(multiclass_roc_auc_score(y_test,y_scored))
# Out:
# [11 10 11 10 11 11 11 10 11 10 11 11 11 11 11 11 10 10 11 10 11 11 11 11
#  10 11 11 11 10 11 11 11 11 11 11 11 10 11 11 10 11 11 11 10 11 11 11 11
#  10 11 11 11 11 10 11 11 11 11 11 11 11 11 11 11 10 11 10 11 11 10 11 11
#  10 11 11 11 10 11 11 10 11 10 11 11 11 11 11 10 11 11 10 11 10 11 11 11
#  11 11 11 11 11 11 11 10 10 10 10 11 10 11 11 11 10 10 11 11 11 10 11 11
#  11 11 10 10 11 11 11 11 10 10 11 11 11 11 11 10 11 11 10 11 10 10 11 10
#  11 11 11 11 11 11 10 11 10 11 11 11 11 11 11 10 11 10 10 11 11 11 11 11
#  11 11 10 10 11 10 11 11 11 11 10 11 10 11 11 11 11 11 11 11 11 10 11 11
#  11 10 10 11 11 11 10 11 10 11 10 11 10 11 11 11 10 11 11 11 11 11 11 11
#  11 11 11 11 11 11 11 10 11 11 11 10 11 10 11 11 11 11 11 10 11 10 11 11
#  11 11 11 11 11 11 11 10 11 11 11 11 11 10 11 11 10 11 11 11 10 11 11 10
#  11 11 11 11 11 11 11 10 11 10 10 11 11 11 11 11 11 10 11 11 11 11 10 11
#  11 11 11 10 11 10 11 11 11 11 11 11 10 10 10 11 10 11 11 11 11 11 10 11
#  11 11]
# ...

# %%
 roc_values
# Out:
# [0.5021074788303886,
#  0.5,
#  0.5101073174458803,
#  0.4938520208096736,
#  0.5,
#  0.5016090058505389,
#  0.5140938134243629,
#  0.4979598319028476,
#  0.4977453142722396,
#  0.5009503983803554,
#  0.508030300380159,
#  0.5,
#  0.5031552679286206,
#  0.5020151873378629,
#  0.5018026250822272,
#  0.5,
#  0.4992645625438286,
#  0.5,
#  0.5001975322935478,
#  0.5031444814337311,
#  0.5,
#  0.5,
#  0.5,
#  0.5006720660479389,
#  0.49666580173018327,
#  0.4941750406481361,
#  0.5012210139615487,
#  0.4986473363854494,
#  0.5087718439350857,
#  0.5180683773606694,
#  0.5770207144695021,
#  0.7004983015080788]

# %%
roc_values=pd.Series(roc_values)
roc_values.index=X_train.columns
roc_values.sort_values(ascending=True).nlargest(10)
# Out:
# G2            0.700498
# G1            0.577021
# absences      0.518068
# Medu          0.514094
# age           0.510107
# health        0.508772
# reason        0.508030
# traveltime    0.503155
# nursery       0.503144
# school        0.502107
# dtype: float64

# %%
roc_values.nlargest(10).sort_values(ascending=True).plot.barh(figsize=(5,5))

# %% [markdown]
# ## 4.2 Regression

# %% [markdown]
# ## 4.2.1 Decision Tree

# %%
X_train,X_test,y_train,y_test=train_test_split(all,g3,test_size=0.3,random_state=0)

# %%
mse_values_dt =[]

# %%
for feature in X_train.columns:
    clf=DecisionTreeRegressor()
    clf.fit(X_train[feature].to_frame(),y_train)
    y_scored=clf.predict(X_test[feature].to_frame())
    print(y_scored)
    mse_values_dt.append(mean_squared_error(y_test,y_scored))
# Out:
# [11.61595547 10.38219895 11.61595547 10.38219895 11.61595547 11.61595547
#  11.61595547 10.38219895 11.61595547 10.38219895 11.61595547 11.61595547
#  11.61595547 11.61595547 11.61595547 11.61595547 10.38219895 10.38219895
#  11.61595547 10.38219895 11.61595547 11.61595547 11.61595547 11.61595547
#  10.38219895 11.61595547 11.61595547 11.61595547 10.38219895 11.61595547
#  11.61595547 11.61595547 11.61595547 11.61595547 11.61595547 11.61595547
#  10.38219895 11.61595547 11.61595547 10.38219895 11.61595547 11.61595547
#  11.61595547 10.38219895 11.61595547 11.61595547 11.61595547 11.61595547
#  10.38219895 11.61595547 11.61595547 11.61595547 11.61595547 10.38219895
#  11.61595547 11.61595547 11.61595547 11.61595547 11.61595547 11.61595547
#  11.61595547 11.61595547 11.61595547 11.61595547 10.38219895 11.61595547
#  10.38219895 11.61595547 11.61595547 10.38219895 11.61595547 11.61595547
#  10.38219895 11.61595547 11.61595547 11.61595547 10.38219895 11.61595547
# ...

# %%
mse_values_dt =pd.Series(mse_values_dt)

# %%
mse_values_dt.index=X_train.columns

# %%
mse_values_dt.sort_values(ascending=True).nsmallest(10)
# Out:
# G2            2.185494
# G1            3.880225
# failures      9.395439
# higher       10.308597
# Medu         10.531017
# Fedu         10.880225
# studytime    10.949344
# age          11.021257
# Mjob         11.042681
# Dalc         11.078837
# dtype: float64

# %%
mse_values_dt.nsmallest(10).sort_values(ascending=True).plot.barh(figsize=(5,5))

# %% [markdown]
# ## 4.2.2 Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
mse_values_lr =[]
for feature in X_train.columns:
    lr=LinearRegression()
    lr.fit(X_train[feature].to_frame(),y_train)
    y_scored=lr.predict(X_test[feature].to_frame())
    print(y_scored)
    mse_values_lr.append(mean_squared_error(y_test,y_scored))
# Out:
# [11.61595547 10.38219895 11.61595547 10.38219895 11.61595547 11.61595547
#  11.61595547 10.38219895 11.61595547 10.38219895 11.61595547 11.61595547
#  11.61595547 11.61595547 11.61595547 11.61595547 10.38219895 10.38219895
#  11.61595547 10.38219895 11.61595547 11.61595547 11.61595547 11.61595547
#  10.38219895 11.61595547 11.61595547 11.61595547 10.38219895 11.61595547
#  11.61595547 11.61595547 11.61595547 11.61595547 11.61595547 11.61595547
#  10.38219895 11.61595547 11.61595547 10.38219895 11.61595547 11.61595547
#  11.61595547 10.38219895 11.61595547 11.61595547 11.61595547 11.61595547
#  10.38219895 11.61595547 11.61595547 11.61595547 11.61595547 10.38219895
#  11.61595547 11.61595547 11.61595547 11.61595547 11.61595547 11.61595547
#  11.61595547 11.61595547 11.61595547 11.61595547 10.38219895 11.61595547
#  10.38219895 11.61595547 11.61595547 10.38219895 11.61595547 11.61595547
#  10.38219895 11.61595547 11.61595547 11.61595547 10.38219895 11.61595547
# ...

# %%
mse_values_lr =pd.Series(mse_values_lr)
mse_values_lr.index=X_train.columns
mse_values_lr.sort_values(ascending=True).nsmallest(10)
# Out:
# G2            2.113615
# G1            4.170515
# failures      9.640718
# higher       10.308597
# Medu         10.522780
# Fedu         10.857638
# studytime    11.004261
# Dalc         11.005770
# age          11.072356
# goout        11.137201
# dtype: float64

# %%
mse_values_lr.nsmallest(10).sort_values(ascending=True).plot.barh(figsize=(5,5))

# %% [markdown]
# ## 5.Regularisation

# %% [markdown]
# ## 5.1 Linear Regression (Lasso)

# %%
X_train,X_test,y_train,y_test=train_test_split(all,g3,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
sel_=SelectFromModel(Lasso(alpha=0.10))
sel_.fit(scaler.transform(X_train),y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.1, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=None,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
sel_.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True,  True,  True])

# %%
selected_feat = X_train.columns[(sel_.get_support())]

# %%
selected_feat
# Out:
# Index(['failures', 'paid', 'absences', 'G1', 'G2'], dtype='object')

# %%
len(selected_feat)
# Out:
# 5

# %% [markdown]
# ## 5.2 Logistic Regression (Ridge)

# %%
from sklearn.linear_model import LogisticRegression

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
sel_=SelectFromModel(LogisticRegression(C=25,penalty='l2'))
sel_.fit(scaler.transform(X_train),y_train)
# Out:
# C:\Users\ADMIN\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\ADMIN\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# SelectFromModel(estimator=LogisticRegression(C=25, class_weight=None,
#                                              dual=False, fit_intercept=True,
#                                              intercept_scaling=1, l1_ratio=None,
#                                              max_iter=100, multi_class='warn',
#                                              n_jobs=None, penalty='l2',
#                                              random_state=None, solver='warn',
#                                              tol=0.0001, verbose=0,
# ...

# %%
sel_.get_support()
# Out:
# array([False, False, False, False, False, False, False,  True, False,
#        False, False, False,  True, False,  True, False, False,  True,
#        False, False,  True, False,  True, False, False, False,  True,
#        False, False,  True,  True,  True])

# %%
selected_feat = X_train.columns[(sel_.get_support())]

# %%
selected_feat
# Out:
# Index(['Fedu', 'traveltime', 'failures', 'paid', 'higher', 'romantic', 'Dalc',
#        'absences', 'G1', 'G2'],
#       dtype='object')

# %%
len(selected_feat)
# Out:
# 10

# %% [markdown]
# ## 6.Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %% [markdown]
# ## 6.1 Classifier

# %%
sel_ = SelectFromModel(RandomForestClassifier(n_estimators=10000))
sel_.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(bootstrap=True,
#                                                  class_weight=None,
#                                                  criterion='gini',
#                                                  max_depth=None,
#                                                  max_features='auto',
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=10000,
#                                                  n_jobs=None, oob_score=False,
# ...

# %%
sel_.get_support()
# Out:
# array([False, False,  True, False, False, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True, False,
#         True,  True,  True,  True,  True])

# %%
selected_feat = X_train.columns[(sel_.get_support())]
len(selected_feat)
# Out:
# 10

# %%
selected_feat
# Out:
# Index(['age', 'Fedu', 'Mjob', 'freetime', 'goout', 'Walc', 'health',
#        'absences', 'G1', 'G2'],
#       dtype='object')

# %%
sel_est=sel_.estimator_.feature_importances_

# %%
feature_importance=pd.Series(sel_est)
feature_importance.index=X_train.columns

# %%
pd.DataFrame(feature_importance.sort_values(ascending=False).nlargest(10),columns=['feature_importance'])
# Out:
#           feature_importance
# G2                  0.172150
# G1                  0.107874
# absences            0.062419
# age                 0.039272
# goout               0.037584
# health              0.035664
# freetime            0.035442
# Mjob                0.035008
# Walc                0.034484
# Fedu                0.034346

# %% [markdown]
# ## 6.2 Regressor

# %%
sel_ = SelectFromModel(RandomForestRegressor(n_estimators=10000))
sel_.fit(X_train.fillna(0), y_train)
# Out:
# SelectFromModel(estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                                 max_depth=None,
#                                                 max_features='auto',
#                                                 max_leaf_nodes=None,
#                                                 min_impurity_decrease=0.0,
#                                                 min_impurity_split=None,
#                                                 min_samples_leaf=1,
#                                                 min_samples_split=2,
#                                                 min_weight_fraction_leaf=0.0,
#                                                 n_estimators=10000, n_jobs=None,
#                                                 oob_score=False,
#                                                 random_state=None, verbose=0,
#                                                 warm_start=False),
# ...

# %%
sel_.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False,  True])

# %%
selected_feat = X_train.columns[(sel_.get_support())]
len(selected_feat)
# Out:
# 2

# %%
selected_feat
# Out:
# Index(['absences', 'G2'], dtype='object')

# %%
sel_est=sel_.estimator_.feature_importances_

# %%
feature_importance=pd.Series(sel_est)
feature_importance.index=X_train.columns

# %%
pd.DataFrame(feature_importance.sort_values(ascending=False).nlargest(10),columns=['feature_importance'])
# Out:
#            feature_importance
# G2                   0.823242
# absences             0.058988
# studytime            0.009807
# G1                   0.009438
# age                  0.008783
# famrel               0.007978
# health               0.006663
# reason               0.006350
# goout                0.006311
# freetime             0.005707

# %% [markdown]
# ## 6.3 Recursive feature selection using random forests

# %%
from sklearn.feature_selection import RFE

# %%
sel_ = RFE(RandomForestClassifier(n_estimators=100), n_features_to_select=15)
sel_.fit(X_train.fillna(0), y_train)
# Out:
# RFE(estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                      criterion='gini', max_depth=None,
#                                      max_features='auto', max_leaf_nodes=None,
#                                      min_impurity_decrease=0.0,
#                                      min_impurity_split=None,
#                                      min_samples_leaf=1, min_samples_split=2,
#                                      min_weight_fraction_leaf=0.0,
#                                      n_estimators=100, n_jobs=None,
#                                      oob_score=False, random_state=None,
#                                      verbose=0, warm_start=False),
#     n_features_to_select=15, step=1, verbose=0)

# %%
sel_.get_support()
# Out:
# array([False, False,  True, False, False, False,  True,  True,  True,
#         True,  True, False, False,  True, False, False, False, False,
#        False, False, False, False, False,  True,  True,  True, False,
#         True,  True,  True,  True,  True])

# %%
selected_feat = X_train.columns[(sel_.get_support())]
len(selected_feat)
# Out:
# 15

# %%
selected_feat
# Out:
# Index(['age', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'studytime', 'famrel',
#        'freetime', 'goout', 'Walc', 'health', 'absences', 'G1', 'G2'],
#       dtype='object')

# %%
sel_est=sel_.estimator_.feature_importances_

# %%
feature_importance=pd.Series(sel_est)
feature_importance.index=selected_feat

# %%
pd.DataFrame(feature_importance.sort_values(ascending=False).nlargest(10),columns=['feature_importance'])
# Out:
#           feature_importance
# G2                  0.207977
# G1                  0.133048
# absences            0.081647
# age                 0.056471
# goout               0.055740
# health              0.052090
# Mjob                0.050624
# Walc                0.049776
# freetime            0.049764
# Fedu                0.048255
